# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %%
ingreso_total = tienda["Precio"].sum() + tienda2["Precio"].sum() + tienda3["Precio"].sum() + tienda4["Precio"].sum()
print(f'El ingreso total de las tiendas es = ${ingreso_total}')
# Out:
# El ingreso total de las tiendas es = $4403619200.0

# %%
ingreso_total_tienda = tienda['Precio'].sum()
ingreso_total_tienda2 = tienda2['Precio'].sum()
ingreso_total_tienda3 = tienda3['Precio'].sum()
ingreso_total_tienda4 = tienda4['Precio'].sum()


print(f'El ingreso total de la Tienda 1 es: ${ingreso_total_tienda}')
print(f'El ingreso total de la Tienda 2 es: ${ingreso_total_tienda2}')
print(f'El ingreso total de la Tienda 3 es: ${ingreso_total_tienda3}')
print(f'El ingreso total de la Tienda 4 es: ${ingreso_total_tienda4}')
# Out:
# El ingreso total de la Tienda 1 es: $1150880400.0
# El ingreso total de la Tienda 2 es: $1116343500.0
# El ingreso total de la Tienda 3 es: $1098019600.0
# El ingreso total de la Tienda 4 es: $1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
categorias_tienda1 = tienda['Categoría del Producto'].value_counts()
categorias_tienda2 = tienda2['Categoría del Producto'].value_counts()
categorias_tienda3 = tienda3['Categoría del Producto'].value_counts()
categorias_tienda4 = tienda4['Categoría del Producto'].value_counts()

print("Tienda 1 - Productos vendidos por categoría:\n", categorias_tienda1, "\n")
print("Tienda 2 - Productos vendidos por categoría:\n", categorias_tienda2, "\n")
print("Tienda 3 - Productos vendidos por categoría:\n", categorias_tienda3, "\n")
print("Tienda 4 - Productos vendidos por categoría:\n", categorias_tienda4, "\n")
# Out:
# Tienda 1 - Productos vendidos por categoría:
#  Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
#
# Tienda 2 - Productos vendidos por categoría:
#  Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
#
# Tienda 3 - Productos vendidos por categoría:
#  Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
calificacion_total_tienda = tienda['Calificación'].value_counts()
calificacion_total_tienda2 = tienda2['Calificación'].value_counts()
calificacion_total_tienda3 = tienda3['Calificación'].value_counts()
calificacion_total_tienda4 = tienda4['Calificación'].value_counts()

calificacion_promedio_tienda = tienda['Calificación'].mean()
calificacion_promedio_tienda2 = tienda2['Calificación'].mean()
calificacion_promedio_tienda3 = tienda3['Calificación'].mean()
calificacion_promedio_tienda4 = tienda4['Calificación'].mean()

print(f'Tienda 1: {calificacion_total_tienda} \n')
print(f'Tienda 2: {calificacion_total_tienda2} \n')
print(f'Tienda 3: {calificacion_total_tienda3} \n')
print(f'Tienda 4: {calificacion_total_tienda4} \n')

print(f'El promedio de la tienda 1 es: {calificacion_promedio_tienda}')
print(f'El promedio de la tienda 2 es: {calificacion_promedio_tienda2}')
print(f'El promedio de la tienda 3 es: {calificacion_promedio_tienda3}')
print(f'El promedio de la tienda 4 es: {calificacion_promedio_tienda4}')
# Out:
# Tienda 1: Calificación
# 5    1292
# 4     444
# 1     319
# 3     218
# 2      86
# Name: count, dtype: int64
#
# Tienda 2: Calificación
# 5    1302
# 4     482
# 1     273
# 3     209
# 2      93
# Name: count, dtype: int64
#
# Tienda 3: Calificación
# 5    1356
# 4     434
# 1     297
# 3     193
# 2      79
# Name: count, dtype: int64
#
# Tienda 4: Calificación
# 5    1300
# 4     453
# 1     310
# 3     210
# 2      85
# Name: count, dtype: int64
#
# El promedio de la tienda 1 es: 3.976685036032217
# El promedio de la tienda 2 es: 4.037303942348453
# El promedio de la tienda 3 es: 4.048325561678677
# El promedio de la tienda 4 es: 3.9957591178965224

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
productos_tienda1 = tienda['Producto'].value_counts()
producto_mas_vendido_1 = productos_tienda1.idxmax()
producto_menos_vendido_1 = productos_tienda1.idxmin()

productos_tienda2 = tienda2['Producto'].value_counts()
producto_mas_vendido_2 = productos_tienda2.idxmax()
producto_menos_vendido_2 = productos_tienda2.idxmin()

productos_tienda3 = tienda3['Producto'].value_counts()
producto_mas_vendido_3 = productos_tienda3.idxmax()
producto_menos_vendido_3 = productos_tienda3.idxmin()

productos_tienda4 = tienda4['Producto'].value_counts()
producto_mas_vendido_4 = productos_tienda4.idxmax()
producto_menos_vendido_4 = productos_tienda4.idxmin()

print(f"Tienda 1: Más vendido -> {producto_mas_vendido_1},\n          Menos vendido -> {producto_menos_vendido_1}")
print(f"Tienda 2: Más vendido -> {producto_mas_vendido_2},\n          Menos vendido -> {producto_menos_vendido_2}")
print(f"Tienda 3: Más vendido -> {producto_mas_vendido_3},\n          Menos vendido -> {producto_menos_vendido_3}")
print(f"Tienda 4: Más vendido -> {producto_mas_vendido_4},\n          Menos vendido -> {producto_menos_vendido_4}")
# Out:
# Tienda 1: Más vendido -> Microondas,
#           Menos vendido -> Auriculares con micrófono
# Tienda 2: Más vendido -> Iniciando en programación,
#           Menos vendido -> Juego de mesa
# Tienda 3: Más vendido -> Kit de bancas,
#           Menos vendido -> Bloques de construcción
# Tienda 4: Más vendido -> Cama box,
#           Menos vendido -> Guitarra eléctrica

# %%
top5_tienda1 = productos_tienda1.head(5)
plt.figure(figsize=(8,5))
top5_tienda1.plot(kind='bar', color='skyblue')
plt.title("Tienda 1 - Top 5 Productos Más Vendidos")
plt.xlabel("\n Producto")
plt.ylabel("Cantidad Vendida\n")
plt.xticks(rotation=0)
plt.show()

# %%
top5_tienda2 = productos_tienda2.head(5)
plt.figure(figsize=(10,5))
top5_tienda2.plot(kind='bar', color='skyblue')
plt.title("Tienda 2 - Top 5 Productos Más Vendidos")
plt.xlabel("\n Producto")
plt.ylabel("\nCantidad Vendida\n")
plt.xticks(rotation=0)
plt.show()

# %%
top5_tienda3 = productos_tienda3.head(5)
plt.figure(figsize=(10,5))
top5_tienda3.plot(kind='bar', color='skyblue')
plt.title("Tienda 3 - Top 5 Productos Más Vendidos")
plt.xlabel("\n Producto")
plt.ylabel("\nCantidad Vendida\n")
plt.xticks(rotation=0)
plt.show()

# %%
top5_tienda4 = productos_tienda4.head(5)
plt.figure(figsize=(10,5))
top5_tienda4.plot(kind='bar', color='skyblue')
plt.title("Tienda 4 - Top 5 Productos Más Vendidos")
plt.xlabel("\n Producto")
plt.ylabel("\nCantidad Vendida\n")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.

# %%
CostoDeEnvio_PromedioTotal_tienda1 = tienda['Costo de envío'].sum() / len(tienda['Costo de envío'])
CostoDeEnvio_PromedioTotal_tienda2 = tienda2['Costo de envío'].sum() / len(tienda2['Costo de envío'])
CostoDeEnvio_PromedioTotal_tienda3 = tienda3['Costo de envío'].sum() / len(tienda3['Costo de envío'])
CostoDeEnvio_PromedioTotal_tienda4 = tienda4['Costo de envío'].sum() / len(tienda4['Costo de envío'])

print(f'El promedio del costo de envio total de la Tienda 1 es: ${CostoDeEnvio_PromedioTotal_tienda1}')
print(f'El promedio del costo de envio total de la Tienda 2 es: ${CostoDeEnvio_PromedioTotal_tienda2}')
print(f'El promedio del costo de envio total de la Tienda 3 es: ${CostoDeEnvio_PromedioTotal_tienda3}')
print(f'El promedio del costo de envio total de la Tienda 4 es: ${CostoDeEnvio_PromedioTotal_tienda4}')
# Out:
# El promedio del costo de envio total de la Tienda 1 es: $26018.60958033065
# El promedio del costo de envio total de la Tienda 2 es: $25216.235693090293
# El promedio del costo de envio total de la Tienda 3 es: $24805.680373039424
# El promedio del costo de envio total de la Tienda 4 es: $23459.457167090754

# %% [markdown]
# # 6. Visualizaciones

# %% [markdown]
# Ingreso total de cada tienda

# %%
ingresos_Totales = [ingreso_total_tienda, ingreso_total_tienda2, ingreso_total_tienda3, ingreso_total_tienda4]
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

plt.figure(figsize=(5, 5))
plt.bar(tiendas, ingresos_Totales, color='skyblue')
plt.title("Ingreso Total por Tienda")
plt.xlabel("\nTienda")
plt.ylabel("\nIngreso Total ($)\n")
plt.ticklabel_format(style='plain', axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# Promedio de calificacion de las 4 tiendas

# %%
ranking_promedios = [
    calificacion_promedio_tienda,
    calificacion_promedio_tienda2,
    calificacion_promedio_tienda3,
    calificacion_promedio_tienda4
]
ranking_tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

plt.figure(figsize=(8, 5))
plt.plot(ranking_tiendas, ranking_promedios, marker='o', linestyle='-', color='green')
plt.title("Promedio de Calificación por Tienda")
plt.xlabel("\nTienda")
plt.ylabel("\nPromedio de Calificación\n")
plt.ylim(min(ranking_promedios) - 0.1, max(ranking_promedios) + 0.1)
plt.grid(True)
plt.show()

# %% [markdown]
# Categorias de productos y su venta en cada tienda

# %%
ProductosCategoria = pd.DataFrame({
    'Tienda 1': categorias_tienda1,
    'Tienda 2': categorias_tienda2,
    'Tienda 3': categorias_tienda3,
    'Tienda 4': categorias_tienda4
})


plt.figure(figsize=(14, 8))
ProductosCategoria.plot(kind='bar', figsize=(14, 8))
plt.title("Ventas por Categoría y por Tienda", fontsize=18, fontweight='bold',)
plt.xlabel("\nCategoría del Producto", fontsize=15, fontweight='bold', labelpad=10)
plt.ylabel("Cantidad Vendida \n", fontsize=15, fontweight='bold', labelpad=10)
plt.xticks(rotation=45, ha='right')
plt.legend(title="Tienda")
plt.tight_layout()
plt.show()

# %% [markdown]
# El costo de envio de cada tienda en porcentaje

# %%
tiendas_costoDeEnvio = ['Tienda1', 'Tienda2', 'Tienda3', 'Tienda4']
ranking_costoDeEnvio = [CostoDeEnvio_PromedioTotal_tienda1, CostoDeEnvio_PromedioTotal_tienda2, CostoDeEnvio_PromedioTotal_tienda3, CostoDeEnvio_PromedioTotal_tienda4]

plt.pie(ranking_costoDeEnvio, labels=tiendas_costoDeEnvio, autopct='%1.1f%%', colors=['red', 'yellow', 'green', 'blue'], shadow=True, )
plt.title("Costo de envio de cada tienda\n")
plt.show()

# %% [markdown]
# # **Informe final**

# %% [markdown]
# ## **Objetivo del analisis**
#
# El objetivo del analisis fue comparar las 4 tiendas del Sr. Juan en distintas categorias como su facturacion, calificacion, envios, etc y de esta forma indicar cual es la mejor opcion para cerrar definitivamente.

# %% [markdown]
# ### **Primer analisis (Facturacion)**
#
# Para esto se empezo analizando la facturacion de cada tienda. De un total de ingresos de **$4403619200.0** cada tienda facturaba:
#
# Tienda 1 es: **$1150880400.0**
#
# Tienda 2 es: **$1116343500.0**
#
# Tienda 3 es: **$1098019600.0**
#
# Tienda 4 es: **$1038375700.0**
#
# por lo que visto en el grafico de abajo, la tienda 4 es la que menos ingresos genera.

# %%
ingresos_Totales = [ingreso_total_tienda, ingreso_total_tienda2, ingreso_total_tienda3, ingreso_total_tienda4]
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

plt.figure(figsize=(5, 5))
plt.bar(tiendas, ingresos_Totales, color='skyblue')
plt.title("Ingreso Total por Tienda")
plt.xlabel("\nTienda")
plt.ylabel("\nIngreso Total ($)\n")
plt.ticklabel_format(style='plain', axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Segundo analisis (ventas por categoria)**
#
# Se analizo las categorias de los productos mas populares de las tiendas individualmente y acá para mejor apreciacion se muestran juntas. Como se puede ver a simple vista la categoria mas popular Muebles, seguida por Electronicos y Juguetes en todas las tiendas suele ser la misma.

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle("Categorías de Producto Más Populares por Tienda\n\n\n", fontsize=16)


axs[0, 0].bar(categorias_tienda1.index, categorias_tienda1.values, color='skyblue')
axs[0, 0].set_title("Tienda 1")
axs[0, 0].tick_params(axis='x', rotation=45)


axs[0, 1].bar(categorias_tienda2.index, categorias_tienda2.values, color='lightgreen')
axs[0, 1].set_title("Tienda 2")
axs[0, 1].tick_params(axis='x', rotation=45)


axs[1, 0].bar(categorias_tienda3.index, categorias_tienda3.values, color='salmon')
axs[1, 0].set_title("Tienda 3")
axs[1, 0].tick_params(axis='x', rotation=45)


axs[1, 1].bar(categorias_tienda4.index, categorias_tienda4.values, color='plum')
axs[1, 1].set_title("Tienda 4")
axs[1, 1].tick_params(axis='x', rotation=45)

plt.tight_layout(rect=[0, 0, 1, 1])
plt.show()

# %% [markdown]
# ### **Tercer analisis(Calificacion promedio)**
#
# En este analisis se calculo el promedio de calificacion entre 1 y 5 de cada tienda. Esto nos ayuda a ver la satisfaccion de los clientes y el desempeño de la tienda.
#
# La tienda 1 y la tienda 4 estan por debajo de la calificacion 4.

# %%
ranking_promedios = [
    calificacion_promedio_tienda,
    calificacion_promedio_tienda2,
    calificacion_promedio_tienda3,
    calificacion_promedio_tienda4
]
ranking_tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

plt.figure(figsize=(8, 5))
plt.plot(ranking_tiendas, ranking_promedios, marker='o', linestyle='-', color='green')
plt.title("Promedio de Calificación por Tienda")
plt.xlabel("\nTienda")
plt.ylabel("\nPromedio de Calificación\n")
plt.ylim(min(ranking_promedios) - 0.1, max(ranking_promedios) + 0.1)
plt.grid(True)
plt.show()

# %% [markdown]
# ### **Cuarto analisis (Productos mas y menos vendidos)**
# Para este analisis se priorizo que productos se venden mas y que productos se venden menos y asi tener una vista mas especifica de todas las tiendas.
#
# El primer grafico muestra todos los productos y cuanto se venden en cada tienda.
#
# En el segundo grafico se muestra un top 5 de los productos mas vendidos en cada tienda y en el tercero un grafico con el top 5 de menos ventas.

# %%
ProductosCategoria = pd.DataFrame({
    'Tienda 1': productos_tienda1,
    'Tienda 2': productos_tienda2,
    'Tienda 3': productos_tienda3,
    'Tienda 4': productos_tienda4
})


plt.figure(figsize=(19, 10))
ProductosCategoria.plot(kind='bar', figsize=(40, 6))
plt.title("Ventas por producto y por Tienda", fontsize=18, fontweight='bold',)
plt.xlabel("\nProducto", fontsize=15, fontweight='bold', labelpad=10)
plt.ylabel("Cantidad Vendida \n", fontsize=15, fontweight='bold', labelpad=10)
plt.xticks(rotation=45, ha='right')
plt.legend(title="Tienda")
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 8))
fig.suptitle("Top 5 Productos Más Vendidos por Tienda", fontsize=16)


productos_tienda1.head(5).plot(kind='bar', ax=axs[0, 0], color='skyblue')
axs[0, 0].set_title("Tienda 1", fontsize=12)
axs[0, 0].set_ylabel("Cantidad vendida")
axs[0, 0].set_xlabel("\nProducto\n")
axs[0, 0].tick_params(axis='x', labelsize=8, rotation=45)


productos_tienda2.head(5).plot(kind='bar', ax=axs[0, 1], color='lightgreen')
axs[0, 1].set_title("Tienda 2", fontsize=12)
axs[0, 1].set_ylabel("Cantidad vendida")
axs[0, 1].set_xlabel("\nProducto\n")
axs[0, 1].tick_params(axis='x', labelsize=8, rotation=45)


productos_tienda3.head(5).plot(kind='bar', ax=axs[1, 0], color='salmon')
axs[1, 0].set_title("Tienda 3", fontsize=12)
axs[1, 0].set_ylabel("Cantidad vendida")
axs[1, 0].set_xlabel("\nProducto\n")
axs[1, 0].tick_params(axis='x', labelsize=8, rotation=45)


productos_tienda4.head(5).plot(kind='bar', ax=axs[1, 1], color='plum')
axs[1, 1].set_title("Tienda 4", fontsize=12)
axs[1, 1].set_ylabel("Cantidad vendida")
axs[1, 1].set_xlabel("\nProducto\n")
axs[1, 1].tick_params(axis='x', labelsize=8, rotation=45)


plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 8))
fig.suptitle("Top 5 Productos Menos Vendidos por Tienda", fontsize=16)


productos_tienda1.tail(5).plot(kind='bar', ax=axs[0, 0], color='skyblue')
axs[0, 0].set_title("Tienda 1", fontsize=12)
axs[0, 0].set_ylabel("Cantidad vendida")
axs[0, 0].set_xlabel("\nProducto\n")
axs[0, 0].tick_params(axis='x', labelsize=8, rotation=45)


productos_tienda2.tail(5).plot(kind='bar', ax=axs[0, 1], color='lightgreen')
axs[0, 1].set_title("Tienda 2", fontsize=12)
axs[0, 1].set_ylabel("Cantidad vendida")
axs[0, 1].set_xlabel("\nProducto\n")
axs[0, 1].tick_params(axis='x', labelsize=8, rotation=45)


productos_tienda3.tail(5).plot(kind='bar', ax=axs[1, 0], color='salmon')
axs[1, 0].set_title("Tienda 3", fontsize=12)
axs[1, 0].set_ylabel("Cantidad vendida")
axs[1, 0].set_xlabel("\nProducto\n")
axs[1, 0].tick_params(axis='x', labelsize=8, rotation=45)


productos_tienda4.tail(5).plot(kind='bar', ax=axs[1, 1], color='plum')
axs[1, 1].set_title("Tienda 4", fontsize=12)
axs[1, 1].set_ylabel("Cantidad vendida")
axs[1, 0].set_xlabel("\nProducto\n")
axs[1, 1].tick_params(axis='x', labelsize=8, rotation=45)


plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# ### **Quinto analisis (Promedio de envios)**
# Es necesario saber cuanto se gasta en envios en cada tienda, para eso, se hizo un analisis mostrando el porcentaje de gastos que se realiza en cada tienda.
#
# La tienda 1 es la que mas gastos hace en envios y la tienda 4 es la que menos gastos hace. Hay que tener en cuenta el ingreso de facturacion para un analisis posterior.

# %%
tiendas_costoDeEnvio = ['Tienda1', 'Tienda2', 'Tienda3', 'Tienda4']
ranking_costoDeEnvio = [CostoDeEnvio_PromedioTotal_tienda1, CostoDeEnvio_PromedioTotal_tienda2, CostoDeEnvio_PromedioTotal_tienda3, CostoDeEnvio_PromedioTotal_tienda4]

plt.pie(ranking_costoDeEnvio, labels=tiendas_costoDeEnvio, autopct='%1.1f%%', colors=['red', 'yellow', 'green', 'blue'], shadow=True, )
plt.title("Costo de envio de cada tienda\n")
plt.show()

# %% [markdown]
# ### **Analisis final**
#
# Teniendo en cuenta todo lo mencionado anteriormente se puede decir que la tienda con menor ingreso de facturacion es la ***tienda 4***. Mientras que las ventas por categoria no varia mucho por tienda, es un detalle a apreciar en terminos de mercado general.
#
# Lo que si se puede apreciar es la calificacion promedio donde si bien la tienda 1 es la que menor calificacion tiene, tambien es la que mas ingreso da de todas las tiendas. Por eso es importante mencionar que la tienda 1 y la ***tienda 4*** estan por debajo de la calificacion 4 en promedio.
#
# Y teniendo en cuenta que la tienda 4 es la que menor porcentaje de gastos en envios hace, puede ser un indicador de que es la que menos vende por el primer analisis hecho y por lo tanto no es productiva.
#
# **Mi decision para el Sr.Juan es que si bien no le va tan mal a diferencia de las otras tiendas, la mejor decision para cerrar una de ellas es la tienda 4.**
